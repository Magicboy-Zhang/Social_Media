# %% [markdown]
# seaborn的底层是基于matplotlib的，他们的差异就有点像在餐厅点菜：
#
#     - matplotlib是自己一道菜一道菜的点，虽然费时费力，但是点出来的东西全是特别适合自己的；
#
#     - 但是seaborn就像直接点套餐，特别的简单，所有的东西都是搭配好的，但可能套餐里面总是有些菜不是那么合自己口味
#
# 还有一个原因是，matplotlib比seaborn早上十几年，所以其并不是为了pandas的dataframe设计的。为了实现pandas的dataframe数据的可视化，还必须得先提取每个series，然后通常还需要将它们合并成适当的格式。而seaborn就可以职能的使用dataframe的标签画图。
#
# (**但其实也可以直接往matplotlib中传dataframe的series...)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

iris_df = pd.read_csv('iris.csv')

iris_df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
videoGame_df = pd.read_csv('vgsales.csv')

videoGame_df = videoGame_df.sample(n = 200, random_state = 13)

videoGame_df
# Out:
#         Rank                                               Name Platform  \
# 9617    9619                                 7th Dragon 2020-II      PSP
# 13647  13649                                      Hitman (2016)      PS4
# 6529    6531  Dora the Explorer: The Search for Pirate Pig's...      GBA
# 14695  14698                            Prince of Persia (2008)       PC
# 10901  10903          Etrian Odyssey 2 Untold: Knight of Fafnir      3DS
# ...      ...                                                ...      ...
# 1663    1665                                       Test Drive 4       PS
# 1692    1694     Mario & Sonic at the London 2012 Olympic Games      3DS
# 2571    2573                            Final Fantasy Anthology       PS
# 7715    7717                                         Family Guy      PSP
# 8597    8599           Innocent Life: A Futuristic Harvest Moon      PSP
#
#          Year         Genre             Publisher  NA_Sales  EU_Sales  \
# ...

# %% [markdown]
# ## Scatterplot 散点图

# %%
'''

适用于变量都是数字的情况

seaborn.scatterplot(
    data=None, x=None, y=None, hue=None, 
    size=None, style=None)

data: 传入的数据集，可选。一般是dataframe

x,y: 传入的特征名字或Python/Numpy数据，x表示横轴，y表示纵轴，一般为dataframe中的列。
    如果传入的是特征名字，那么需要传入data，如果传入的是Python/Numpy数据，那么data不
    需要传入。因为Seaborn一般是用来可视化Pandas数据的，如果我们想传入数据，那使用
    Matplotlib也可以。

hue: 分组变量，将产生不同颜色的点。可以是分类的，也可以是数字的。被视为类别。

size: 分组变量，将产生不同大小的点。可以是分类的，也可以是数字的。（用不同大小的标记点来区分类别）

style: 分组变量，将产生不同标记点的变量分组。被视为类别。(用不同样式的标记点区分类别)

'''

plt.figure(figsize = (8, 8))
sns.set_style('whitegrid')
sns.scatterplot(data = iris_df, x = 'SepalLengthCm', y = 'SepalWidthCm', hue = 'Species',
                size = 'SepalLengthCm', style = 'Species')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.relplot(data = videoGame_df, x = 'Year', y = 'NA_Sales')
